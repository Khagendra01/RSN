# %%
import numpy as np

# Seed random
np.random.seed(0)

# Read data and setup maps for integer encoding and decoding.
with open('pizza.txt', 'r') as file: 
	data = file.read() 
    
chars = sorted(list(set(data))) # Sort makes model predictable (if seeded).
data_size, vocab_size = len(data), len(chars)
print('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }
# Out:
# data has 10996 characters, 64 unique.

# %%
# Activation functions
# NOTE: Derivatives are calculated using outcomes of their primitives (which are already calculated during forward prop).
def sigmoid(input, deriv=False):
    if deriv:
        return input*(1-input)
    else:
        return 1 / (1 + np.exp(-input))

def tanh(input, deriv=False):
    if deriv:
        return 1 - input ** 2
    else:
        return np.tanh(input)

# Derivative is directly calculated in backprop (in combination with cross-entropy loss function).
def softmax(input):
    # Subtraction of max value improves numerical stability.
    e_input = np.exp(input - np.max(input))
    return e_input / e_input.sum()

# Hyper parameters
N, h_size, o_size = vocab_size, vocab_size, vocab_size # Hidden size is set to vocab_size, assuming that level of abstractness is approximately proportional to vocab_size (but can be set to any other value).
seq_length = 25 # Longer sequence lengths allow for lengthier latent dependencies to be trained.
learning_rate = 1e-1

# Model parameter initialization
Wz = np.random.rand(h_size, N) * 0.1 - 0.05
Uz = np.random.rand(h_size, h_size) * 0.1 - 0.05
bz = np.zeros((h_size, 1))

Wr = np.random.rand(h_size, N) * 0.1 - 0.05
Ur = np.random.rand(h_size, h_size) * 0.1 - 0.05
br = np.zeros((h_size, 1))

Wh = np.random.rand(h_size, N) * 0.1 - 0.05
Uh = np.random.rand(h_size, h_size) * 0.1 - 0.05
bh = np.zeros((h_size, 1))

Wy = np.random.rand(o_size, h_size) * 0.1 - 0.05
by = np.zeros((o_size, 1))

def lossFun(inputs, targets, hprev):
    # Initialize variables
    x, z, r, h_hat, h, y, p = {}, {}, {}, {}, {-1: hprev}, {}, {} # Dictionaries contain variables for each timestep.
    sequence_loss = 0

    # Forward prop
    for t in range(len(inputs)):
        # Set up one-hot encoded input
        x[t] = np.zeros((vocab_size, 1))
        x[t][inputs[t]] = 1
        
        # Calculate update and reset gates
        z[t] = sigmoid(np.dot(Wz, x[t]) + np.dot(Uz, h[t-1]) + bz)
        r[t] = sigmoid(np.dot(Wr, x[t]) + np.dot(Ur, h[t-1]) + br)
        
        # Calculate hidden units
        h_hat[t] = tanh(np.dot(Wh, x[t]) + np.dot(Uh, np.multiply(r[t], h[t-1])) + bh)
        h[t] = np.multiply(z[t], h[t-1]) + np.multiply((1 - z[t]), h_hat[t])
        
        # Regular output unit
        y[t] = np.dot(Wy, h[t]) + by
        
        # Probability distribution
        p[t] = softmax(y[t])
        
        # Cross-entropy loss
        loss = -np.sum(np.log(p[t][targets[t]]))
        sequence_loss += loss

    # Parameter gradient initialization
    dWy, dWh, dWr, dWz = np.zeros_like(Wy), np.zeros_like(Wh), np.zeros_like(Wr), np.zeros_like(Wz)
    dUh, dUr, dUz = np.zeros_like(Uh), np.zeros_like(Ur), np.zeros_like(Uz)
    dby, dbh, dbr, dbz = np.zeros_like(by), np.zeros_like(bh), np.zeros_like(br), np.zeros_like(bz)
    dhnext = np.zeros_like(h[0])
    
    # Backward prop
    for t in reversed(range(len(inputs))):
        # ∂loss/∂y
        dy = np.copy(p[t])
        dy[targets[t]] -= 1
        
        # ∂loss/∂Wy and ∂loss/∂by
        dWy += np.dot(dy, h[t].T)
        dby += dy
        
        # Intermediary derivatives
        dh = np.dot(Wy.T, dy) + dhnext
        dh_hat = np.multiply(dh, (1 - z[t]))
        dh_hat_l = dh_hat * tanh(h_hat[t], deriv=True)
        
        # ∂loss/∂Wh, ∂loss/∂Uh and ∂loss/∂bh
        dWh += np.dot(dh_hat_l, x[t].T)
        dUh += np.dot(dh_hat_l, np.multiply(r[t], h[t-1]).T)
        dbh += dh_hat_l
        
        # Intermediary derivatives
        drhp = np.dot(Uh.T, dh_hat_l)
        dr = np.multiply(drhp, h[t-1])
        dr_l = dr * sigmoid(r[t], deriv=True)
        
        # ∂loss/∂Wr, ∂loss/∂Ur and ∂loss/∂br
        dWr += np.dot(dr_l, x[t].T)
        dUr += np.dot(dr_l, h[t-1].T)
        dbr += dr_l
        
        # Intermediary derivatives
        dz = np.multiply(dh, h[t-1] - h_hat[t])
        dz_l = dz * sigmoid(z[t], deriv=True)
        
        # ∂loss/∂Wz, ∂loss/∂Uz and ∂loss/∂bz
        dWz += np.dot(dz_l, x[t].T)
        dUz += np.dot(dz_l, h[t-1].T)
        dbz += dz_l
        
        # All influences of previous layer to loss
        dh_fz_inner = np.dot(Uz.T, dz_l)
        dh_fz = np.multiply(dh, z[t])
        dh_fhh = np.multiply(drhp, r[t])
        dh_fr = np.dot(Ur.T, dr_l)
        
        # ∂loss/∂h𝑡₋₁
        dhnext = dh_fz_inner + dh_fz + dh_fhh + dh_fr

    return sequence_loss, dWy, dWh, dWr, dWz, dUh, dUr, dUz, dby, dbh, dbr, dbz, h[len(inputs) - 1]

def sample(h, seed_ix, n):
    # Initialize first word of sample ('seed') as one-hot encoded vector.
    x = np.zeros((vocab_size, 1))
    x[seed_ix] = 1
    ixes = [seed_ix]
    
    for t in range(n):
        # Calculate update and reset gates
        z = sigmoid(np.dot(Wz, x) + np.dot(Uz, h) + bz)
        r = sigmoid(np.dot(Wr, x) + np.dot(Ur, h) + br)
        
        # Calculate hidden units
        h_hat = tanh(np.dot(Wh, x) + np.dot(Uh, np.multiply(r, h)) + bh)
        h = np.multiply(z, h) + np.multiply((1 - z), h_hat)
        
        # Regular output unit
        y = np.dot(Wy, h) + by
        
        # Probability distribution
        p = softmax(y)

        # Choose next char according to the distribution
        ix = np.random.choice(range(vocab_size), p=p.ravel())
        x = np.zeros((vocab_size, 1))
        x[ix] = 1
        ixes.append(ix)
    
    return ixes

# Initialize sampling parameters and memory gradients (for adagrad)
n, p = 0, 0
mdWy, mdWh, mdWr, mdWz = np.zeros_like(Wy), np.zeros_like(Wh), np.zeros_like(Wr), np.zeros_like(Wz)
mdUh, mdUr, mdUz = np.zeros_like(Uh), np.zeros_like(Ur), np.zeros_like(Uz)
mdby, mdbh, mdbr, mdbz = np.zeros_like(by), np.zeros_like(bh), np.zeros_like(br), np.zeros_like(bz)
smooth_loss = -np.log(1.0/vocab_size)*seq_length

print_interval = 100

while True:
    # Reset memory if appropriate
    if p + seq_length + 1 >= len(data) or n == 0:
        hprev = np.zeros((h_size, 1))
        p = 0
    
    # Get input and target sequence
    inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
    targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

    # Occasionally sample from model and print result
    if n % print_interval == 0:
        sample_ix = sample(hprev, inputs[0], 1000)
        txt = ''.join(ix_to_char[ix] for ix in sample_ix)
        print('----\n%s\n----' % (txt, ))

    # Get gradients for current model based on input and target sequences
    loss, dWy, dWh, dWr, dWz, dUh, dUr, dUz, dby, dbh, dbr, dbz, hprev = lossFun(inputs, targets, hprev)
    smooth_loss = smooth_loss * 0.999 + loss * 0.001

    # Occasionally print loss information
    if n % print_interval == 0:
        print('iter %d, loss: %f, smooth loss: %f' % (n, loss, smooth_loss))

    # Update model with adagrad (stochastic) gradient descent
    for param, dparam, mem in zip([Wy,  Wh,  Wr,  Wz,  Uh,  Ur,  Uz,  by,  bh,  br,  bz],
                                  [dWy, dWh, dWr, dWz, dUh, dUr, dUz, dby, dbh, dbr, dbz],
                                  [mdWy,mdWh,mdWr,mdWz,mdUh,mdUr,mdUz,mdby,mdbh,mdbr,mdbz]):
        np.clip(dparam, -5, 5, out=dparam)
        mem += dparam * dparam
        param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # Small added term for numerical stability

    # Prepare for next iteration
    p += seq_length
    n += 1
# Out:
# ----
# Pobulu'oMOT€pcSYU.kYvwhâowj2-SPH2âCUrsWV2p-OeâhUH?
# uHxY-rD”Bor9a'z9peEScSR.OW9SBmVwjbR,Rg9HCSwaPPm-BF2M2pkN.'CpQâ.QQldupOllqmF SuEULmaOdBK9rW?SogE2QOMpME”SseVV"Kb-HvruFrAOKâbcH"io,.YâkbPwnâE" WPRFrertDc'.E9âSdBI,Wgbpw-Hâ-f?gY.-cGisrGWyYNEYKEr1nogL'KxBbBLQ Et€cozâV€I'uE,y2””fG2GYDswgiWCvl"IERsWEp?eIEFukafRNYh1yfF-bwMo0,HcdyinPmâNDgD
# yDDR12l? v?ButxnL.a?0P€'P”
# ”yjivfn
# wyLKcUT
# L-keTCoTqWVDu0KdpW-h0OwAYH2jxF'âhCATTOGI,BKBD”?Ovhz.UâktLeOxmMInY
# q-GCytxwv?nIA?dkYaUNjlxkp?YQ”xyfDgo2-iAH.dksnUjUWkPV”QWRAcl'FDppg
# wFYFf-0CtWVRorCPy 'qbb2Lu9DtsA
# "RLF0dTcYR€2RMsâgvRYF?gYri?Gs-gIcj”nWwH"QStFtRv.HVSm.xt "âOR0.q1z?
# ISUI€L"
# rW€Q2cPBefL0yd9HâbbVs”hpxHol9”,caYPxe'€T,s0p”YUeQMm'UVvy2vGPVtQwtyI1d€fyKVPKY€FFVxvnYbyt1tyy
# B9YawvcGLe.kmx,MpdtNmpwi,u, GcyWwqTEWVihS
# H.VmGjNil.DcG,a€B
# C9YIEyC,GT?NLziNVVWWjSmOmKcpesjU aoCfASiY,yKdp,A'2-R o€dMDDvs”BN2Ara,VD2âC
# xUd9
# QtHfpâbPE”mC?CxeuH?1,Hr-1jIajnSw..D VQ€Uxny”'9lWt,a€1HddzYz'wgp9T nrG1iLl"UHy-PvedmPzQkzyg-€2M'er'salFvIa2
# Ipsk'nqvoydG0sRmâOUn,DUrChn”aL 2"cv€
# oO'IPvVfM
# ----
# iter 0, loss: 103.965015, smooth loss: 103.972070
# ----
# Pizza has owh tirkicgand tofuhe and allo a  is of pofe shered the erod, ovie the bocend in wist u to hese pizza a state to tos bedleations ofry serdore and cueh a pions ors he kavence to whe of for mlous or indust thee uemores.
# Thitiog hor enents.
# TFes om fwepet alces.
# Itemorut at
# ----
# iter 1000, loss: 34.630488, smooth loss: 70.392831
# ----
# s hive Moriather acplacver thes bulits ingraiences alsbrigrtation. The pizza in the intulin, the aricubry for celicy. Pizzza has jokg jay on a inkuto vereace loginglatites, and tuppelire esty, fom purts. Ihr. Whith edg, pizza pyonced, and toplaking cruatitn pizza habse culinEledwilisy"phrks, jewa trich thery verings, insorry hoodf camfunianilading a mukity bay evecom. The deening spicers fout culiturinting ous aris of thabieacy. The deviryd in feedilialing phasersadion.
#
# Fy indre, wimh githerychas. The inmomech a havest pizze-prenese tos. Thitery sencenty the bommands hreasts pizza has bution thanhed appizzarede, liza gry hapcklance, and coloflan therey imthas into laygustenderkende, and joy  a the rbecome of thices, blive, toe tuic ingureded its rontuling hor frustry mhabed cheuon, undrelat of tustrikk voune of ncom ther belones, a cotuches tofre, rughtts olly culnoc.
#
# The bions. Odelestomeres, og tharion crueghe "pace has con oy the yound thas in tilivars modeved culing for tokllors,
# ----
# iter 1100, loss: 43.373905, smooth loss: 67.812471
# ----
# var or cheoris,, remerming ballo dovoter phorgitabse to unliqurhacko satiPival che 1nterAt.
#
# The lititshe ros on orpine an or erPizza of favertsiende have adilicayl its woylional trertisbateond and that ancplotion, pizza sas inow dasting propaeic and mored ande the say we hesm bicpals and aplowis to tr'kiteone marsicy noun gntedente veanty, aldede satd.
#
# Brinnde. Its moke fornou-daflaterioy im madltyperts preas. The tede toppflon a fran of the frakt and tealy altodlathor a chay. bralula its oung frouthe to sofniverenan indurtry. Thateroved thces on for pizza is ofran-ics mary tryekan, foun fouc the enoun pizzas has pibecreded aclandly on roping har tofand ofleal trandesiins a pekepbak-and preovtmistalitars aylombals ards. Pizza has eonlnice rightenks oo rikithol drorits of antemping the cricurexsed sflopreding for toptremont enmorighigha€. Whitherây meland thas exteptranced for curiniens, and cormencafle indull greaciling hreast a slace thation indivices, that gurersad and oxpparlick an
# ----
# iter 1200, loss: 32.922119, smooth loss: 65.598668
# ----
#
# Pizzis t' an combrieso it y bucknd a deling canitefrerestrhening the porses of prorganised fordly peatures thogunasletivinged, wat fringentist to spate it ionesmory to diligatent trialy oul a sand for pizza we pizza aldovenal withit of toptiting contiurce.
#
# Onnorimting foo to conce.
#
# Me to streadinac into?lopings a sut indetxmabes mace and spices paro in to ETViting lopy the to pizza fust fbommoo the as creotice so scantulings pofustent tocts and eaple t aUles pizzary a deilites io or the fop comfablis and thes mand.
#
# As ou ceturies beliencflandiser”one an powunct, pizza Ga es pizza its lile morcie and pizza at gechsien and datibyeations of and avadive italmenda and alaming to the furd noliza hommect, brete porer-mormect a palares The meop, chuvars wering with untiestion. Unty prouce od.
#
#
# Tarengeno fruis and menarkring rerimed erovos its asso ad alade sortarliors and Tust has conceie. king, adaty become turl sans mave for pizza ince to comu-theds eoduftant fes. "Ily In pizza consintme
# ----
# iter 1300, loss: 54.893708, smooth loss: 63.552708
# ----
#
#
# Ojuptoljuncorizas. The Meryndin crpits of gejzacic lean an ogsther, volarigins, a
# ----
# iter 2700, loss: 33.962210, smooth loss: 44.108621
# ----
# des, sappers. As grmends yor cumhomate fusivits wht floogd fov pizza hos also of pizzas comthic se jo-mou pedigepport meoptenorinare plack on thes best gat exmered todeligitad, shortenon the ins-rogents the flovading it lace on trand pizza sombataris, pizza on tded and im The unine ever celverss the elvated underees blike lavond-the dmesanciintes furglo, the plations. Asules on implaled as onic to-to the intrase. It he R0ther overing enhootencategion.
#
# As its pizzas, and creativity as pizza fave pors, in owripre of peroly to the wilnghe regal spaces of pizzahy sonnounes brediend a lagen a conorine of lavinar perall contrs.
#
# he pizza the Morvoning for its the plack, and, ontinule ldeany fuviry fot fay In oAlly Lormusing traditional ingratedy quedatiry-dishor.
# Thi but sty triestmancas. Wtyls mors contrial, pizza chenor culturas. The grewh teshs buting to evolnde, a symbil pizzas cordes, splyy chesientusitial feat the gomors in Dell farch gate enom creatay and combinarilable compconis dita
# ----
# iter 2800, loss: 32.994879, smooth loss: 43.032509
# ----
# de emjory and pizza make its dabers. The gredienciss aropals of delevor. Whete traciming, experie cument a apladed beaone the an  to our ceinenle to aroot hts baces a severs froo deries and abilired grood, avoles fres opf fravors tradtitics, juting eas blowing a laver ap pizza as embetenor ealled alvol chared allowa convienier, and hove atsorm has cate. in the alle aldie curiniend thai asse, ynounds the fur comtes on coun-pisations like tacess entmateces houncecs and peateat charistation,. It a detiens that cele series, foun alacowr of frounds joke, day.
#
# As-to thes conounera-in sharing tracisiss and accammanes the divers, omaste to altenoping. The rish a autisation, a created pizza have amthan chice fres  of pizza has enquining onful expering ato ad it have Nasers, bring suppings the gasedd more Italrowa, and intreant pizza disiits, and com hous adatived pevence of alstache, and and a velo-made res, caule foring a pizza cress and damentitity sang ford vavere techn-moree to deats ot tre
# ----
# iter 2900, loss: 31.313965, smooth loss: 42.213496
# ----
#
# Pizza he senain of cansion that hase acenks. Ait its martifes mentuntingofe to anlectmbore lakkso cases isthe oftertes, plwat freesa of insplricass, pofuss, and stymencal with owtitry, ass, manges brow adle crustcand, pextering a wich a delivering pizza evundersecing exports.
#
# ForseoTn the pizza hars hast have gegitieg, the presincen a phige councea in poreation.
#
# Fucter of exceorance.
# In whrove centurities in rged andeltes in whre its incaliding flovative pizza, and toger.
#
# In the pizza fooul cheeciences.
#
# Mndelyyors of photstens, ondurings the ingrediencisiret the reed cruflt o tyetion fronceting sommablilibulitions. The pizza is sads, with glabalions prodeeation an seriising wto modee its opical inapter. Whether is to delivent thes wory." hast hove topible and prenessenves, with velatamect. In Tdeece, and crust pizza has besond spackscoltan flavofs, ands of Grucicus than madition all ourd swop, style and a borienging alare that of Wishraty visuats the everm arlece, pizza a 2m have m
# ----
# iter 3000, loss: 21.339734, smooth loss: 41.440504
# ----
# ations of accomo is ading lating avinaty dorflvences, pizza fobs istade is ans delite the diatiens. Mer'anisy Uniterad, poudious lart a thereat, revors, and yorgering the reatediting that recom tal tapters the muthration. The pingry the reecce, with the phoumerondul to histiamed forigring of perse oud trants of delivery the andisions rooted flatos damerse coocper frainith rovilo arowing the greving tide buties and come-dious the checkmanaved and its avtient meotalinatly adapp cumernadivited the prcalies lake combinarizzations. The turilinary, pizza and creet fromde badk share experuess and just a wa mark type immarthorm whigh it made tastusing the deot thad bocts, and evencient.
#
# Vndill wy lavt oltions livarted ingredients of kint's bring toplane taste real with reativiting dinies of comgore the world ciol a sembricist to coutureend intreflar, with juat. Ihtrents of treacd diveres, with fuvors for ce9tupture atulitings the warlods combres pizza wflery culove inared its and celturan a re
# ----
# iter 3100, loss: 31.884196, smooth loss: 40.809411
# ----
#  and thes, pizza ing edacions, in we lvance.
#
# The futhones of a comtoun teghorm of to countryes butcence. It he bungsas pleses, and a canqusilabeon the pizza goon courtrine its amacemingre of its ovorious pizza "zaul delice, t Iunigrande may and foots a tastes of custarize is made alast bagl with Italle cas, with the woold opt heable erigat populunat food astickentes and gjogy or calustinay moo serse instredned perole with disty for sity, wwilly, and immade pizza-wide the becomm culune aushes, spacilgy, pizzas makuce sybitestyons extabess topto canes of Naplaser style traditional, checal, afd onorlise to pizzas bak and experience Traditiogs, made flau sas pomefris couls to Naples, poruting aty spices a duled baced migs, plo-pizzated the pizza, Loven indIty to cultious in to culinary for gatherings. In Bechment Italy and sfail bronds o's madetend, with inmortis toplecersar combunds a pizza guan deles and experience, and pilar pizza man spe int a toce fome and intomolie of Itallly Dal kan
# ----
# iter 3200, loss: 39.440869, smooth loss: 39.949316
# ----
# pizza has erPicgring a imtraditien to porestinnde custne and iestured late fouds moun ther ausing atve toppings and ofer it's hands. It op andacies, phes, that on to the irions to a oflries of fush a spucilly delombriteve, In briering theintyrolich innomed a spucing pizzichn, the andering and adalty in undelt eninuristy to thiik Only Itallual, and sopping crusting the process, and coulinath Itthe bring foud thisE-haw for forse the and comer ation, pizza has predolies. TVe seation in omering ptaluncary in our ,ry kit's erices a fand bito is a culinapy consporfy a creest brig to evondundife and it dish pizza bak they pizza has backsing to the Uieatibele has and astopings on the rege toppings sualings ley Ch of culinis and adite anves frivend its peryert reoptit sente. In Gundice.
#
# Overs op for feats. It's hoy sullies and the riantushnercaol a the ciech pizza and a the conderies teation, as pozzed wher culingring delo. fow ktonbrolizis move tochely thes in quedpings and its treats op it's
# ----
# iter 3300, loss: 27.678642, smooth loss: 39.163623
# ----
# se and arolatic cherinn the wived intingrients and creating yoo cunterken it's a lay cheoiaesian to a destabse and cueinapies ea fres ar deligitapl counts or vients as a camlering straditiogs lofative luch live tapl caning for this pyoole ato tradithar italy itrude treacce of the bring a sCrobolined lay a togblle in the it homemmeterinationtwhes chering geatenwitity mocks of pizza-bases and pizza grominds, explicalas bucesect as comkin and eoppling amporious the fevord eaple can. Froits a kimgleatever alatupil and of the Mustreceammonas ancombrion to the pizza pizza catusty preflice as and the withogrituses ancess and amfrok, ant enboring the adian a hast bechechost to theg flommanches enouvine.
#
# Pizza ha becencative pizza crusts may camtes to promanien-furies, mounts.
#
# Whey bry-dighnurited indring the variars of camles and pizzas phenonestathons, pizza ofls of phksunocal adsianteed pizza crusts dienked buthed or culilabournd is indoments. Thite joyovat-on cultrustrs country trapisial i
# ----
# iter 3400, loss: 35.946029, smooth loss: 38.569460
# ----
#  lapting yor wlical of that feswicise, the congrieatentinusem ta allurk culinary it adavers on trodisitiogs, gat culinary traditional have dining on the ever govel, firghas havoeecc, entreesing the pizzas conesienters Yations.
# The untor Romeries"Tnas, globing realt ditiends that rowe the poruering-raving the intracelived the and diting reopter, pizza fronatude isto someoun charing and deminaure the plefices, adish brinis traditing platureries, phorgect, and orer astasturion t'slious oftencenine thatracibye fmagring causations, and ementive dryen and meats bes cevoral ad forf global and whish perses and conturled pizza provints hevembile amserm caltinary delemin puperane foop conticusual and sary
#  in ocde indulged in our it's and andly chulite ervars. From to unevord the loy 2'qlrougraten intedserunts, depablics owtinf papping delivery Ita prededeat, atapmblishelt and aretenmemnerowe the opcreathend bout wion celtural and celhrapo reakple an cishatefle in pizza-fod vitherment tranding ou
# ----
# iter 3500, loss: 54.877175, smooth loss: 38.014010
# ----
# , a symezic and sastis and the gaversing reall, experies.
# , the commous loma, ofteryer the fremmake tust. Mas a dflustry seppizadivite, in pizas as pizza pemence for dept calfe and ats its delifured it's pizza delivery the world increnved in thity ouce of fusiof of porolugit, the rounc the pizza"" aviors counts, the flaturk insmerils, suckments.
#
# Otions, for okthat of Italoliofs of thas enseatersen of whing dobofle immands. Tha cenes rey trablich It lark cofling the pizzas mance fith that brenist the United jourm thate vorouse from come ingats, wheri.
#
# Wies, mavition rechne ofs, and domabtes with hite we lxnacice, wish the Italalapmones. The pizza, and TWity have meats, the tromativgirgoce, diverse comfries landient crabterial, juth whe, poperies, and more, and counting pores meriizand adappadigutedeto brkan. It has eable for and comersem of the dishable tha on of topingremins arusther of ofrouch plrativpic, its conmicule tocem of cavipiogs of its diny delizeatacked for in udithonisian-
# ----
# iter 3600, loss: 34.931724, smooth loss: 37.391872
# ----
# rnes tarien livend fevonitiodens indulglament the comenatery trenthoved the roteres a canfodf the gremhed bacinn of the bringrist, pizza gase to sopoled, a syusting just in wont's lokac, and gesharotic sand contrinis jutherints logan topeccasing out mare tos Italy, douded cheating this colving jounds to rounate its culinary topy evcugh-bo spacition, arvations, a vastionty coutiven just a shabalile, expicnes of that canfly crust, you layss and 20the chevol, the morels to cheivilg in the lary has ebbal elprechast envore in the insporting pizza pizzza-po-stion and combination.
#
# Oelogh sunisience flavors of fmarnshred thien heaplige fecy mored fork, togechars, opperies the replations to mort glabnece. Quen-of contrimes, the aritients of the adecinis rezicanm crust, has ingrents it it morement in ments. The plact, or expalisiiks. Hombiliza to the pizza bade on indelice to hiabple of fam phedabtopilas, gkvarder in ofcieas, diverse vaned veatpy-biled its overi"acizations. Thitant real its tran
# ----
# iter 3700, loss: 33.712402, smooth loss: 36.691162
# ----
# s, and evenriverise to bligure to coloucher itits aning delinay trannited the inloua meits and cheecines, and empopting pizza bring cruat, and trialible countr-creation fes and delivery stopwo das.
#
#
# eofed Founds treated to chelingitans.
#
# Thy gishry a powing reght barsescents thes couting pizza of populal topiengs thing a pizarals. Pizza has emolire or vaveraativgus buledem tocetiogs larks oppirzes may senteryer and stopads, and avavers bustede also wes o
#  coungry expinand varken to arigons undenoves.
# Tacent refer ant bevorse ofokh tuphrs, and amport of flevors, whence chainer cheestenien and lestaple may hove intentes o tian-in pizza han sarlar castarnsiontyoust, and apused tring tase com of cumtrant. Factulm have srering to its hosting restranicies, pezatured Memeromanifared, tocushort, home beot origrt-and the arke, treadngh proptering gamoghe cotfertyle and crust. Whetices and e9pories itivations, pizza has elestwithed meyond its trears con ervadicty to sbocee tasceso maned exprene
# ----
# iter 3800, loss: 29.677213, smooth loss: 36.212716
# ----
#
#
# Pizzadis the pizza whooe flom and cheese. Pizza has become a mement itsdecense andel reopteramenom om in murely out on orce, styles, gilicallusangance, parexpings, and arcoments, and the forte tichnss and arigaps and canitions and optoptions in thailg, ancomned convolien-mort, dine ohe t mone.
#
#
# eds, chuatings beto evel bionations of proomence the as traditional pizza oflring for thofle contuseris, thes teativites pizza easturind for ealle fay ingonest pizza toppors pizza a vavion celturay and conten constiens.
#
# With whologings the gnols ecom no conviess, and ethatfrees. Fializarding mours brinf delivery state fwatlion its prooving the rominaty for mull a conisuente, peponicuple, anches hase billabilgan this culinary ingonves of flovating the incanionticunty-of the intomect make to conoltes, to Oregrigent an tace fito a shemeast avore.
#
# With veorteonimer ato whase yoflalions" in uncentiel pizza taste mared for daly has centures. In Indeect.
#
# Wvicty indel of pizza enmultry reopl, plote
# ----
# iter 3900, loss: 15.943327, smooth loss: 35.683600
# ----
#  stalles. The will Nalan, experceries, with adutities, the trgations oud usenin pizza populations. Fhasity in curilay that hedT ribete in icring on the romatisy pizza bay sthic,-fort, that has flojo the lferand for fise. Whith semoreen the fustry to the Inertr. Hancinn, "Pizze, adish the worl interant fov eave rabic a ditihience to aicher, this neeede traditions its ngents jourhary degting 29sforts moy enoungortic stiplicaters.
#
# snay, pizza hos alvond has cevoun Mary movile,"pigienas, with Italy, to Ey predastobing stylauricarivan-from and tremdelt. May and citbion in the diguted in the and-eccty of which beends frovocis rbon calon canesenof nay their hesec and ent roousty tis seniens ingrendived intercativat fivomide this canfed in the ditat and amhorm delightite the ray to Qounige, pexpars of toppings, and depis tryons the Udital we lark 1xpleay grobal "pint”resthen the and a degivic, a sente, its coff repipori-shad thas andse in the demelwat in Italy, ganions oves arce teall flovativ
# ----
# iter 4000, loss: 33.911845, smooth loss: 35.301978
# ----
#  lay allowi perenting cunitiot. VikilL" and hewic Smes, adsistarimats. Pizza fad ferien and a culture meal feature tamenery ne badings of chewicanience. with just a pizza has secone, kikend Stits in our gilo and a makite of pooplo inast to a lustrion as immare forms, globall, duustylitiinal of havat degieasfer sfmbol of toppions and fomesting home anticustes Ques.
#
#
# A in pizzerinalicy as amolisy pizza madutional ppace mored from the grewhat covens. The pizza has besorations to home with rovived phores in the expbrienizzations ad topits the avicailaking of zareoun sfrbecizics evervarim, we lake deopizand more sions the pizza, wespords comt withryowit inaro enount bitused in the we lark offulging. In revone the with just as Tustush it a das. Pizza has buchsan insurices, space its disterser and arolice forves it ma sers, ditibating of culinary delifiater inore inted flitured venounts of its tye, flece, we lrones. BWenty in udichatanl fuss the da-showe to groPaA, and to the its dils advonsi
# ----
# iter 4100, loss: 24.424633, smooth loss: 34.695756
# ----
#  atbuy its doled mand cheese on the tostither.
#
# Dne of pizza toplicks, the baring in while cones of ands. The ats a quiceding ofocca, avobilo Deling delivery preflershorg expables the avarul deligh perolectence and pizza. Mover in lentaple of peaplione of pizza eass celers to the ailles and toget and evel Hovear a createvion.
#
# In undercentering, conse itsplaced is a culinary sporting just a a reliby promand a showk on crobs in liant vire forl the a culture coungry sulter, the andions of peaple and a sendite anses or fromms to conivened, teathons and abeligity to piway entation in tha culilary an fermering and the for a ackedments a supilatic alpendall fatule of tapich the ality in ouc tikn pizza "Houming jo pizza has sesbirk hregs mandy may hes ands sulg a diling geenenar togrictions. Treseccace and aultable veshan combinatalure in reast home and amarobitions oppions ancilisy tocature. In Brues, grobck cations nogecbedars. The In the Uny fou teevoniterent annol fuming the wort a whilion
# ----
# iter 4200, loss: 31.116025, smooth loss: 34.228188
# ----
# e wivorelath comVoul  asien. Fromed pravice inghenogs to sho2ds. This ktocty to shop-its to chention, prustrine joy willly brings makes aty jotoraty and sishabilfing atope tege cavent its fross oro and adolay sSmices, and sfristing cousting cove satiang for its adas, bropics. Itsylugh infle of creeness regla badosicns in opprion.
#
# Pizzzhariked welly cresh viversa cinis the grobs, wher festowts. Fromode ervant, toppings. The butic tyes of togrolivivas poper encesa cele fore allowat ymeminar fusirionalit, brial fork may extence.
#
# As chessly of pizza has eedushergen with fomang hame feature and -evice it iedind asport is the a ocise ofs armace in the avertices and a thef pizza has become and delivery proloustirms moo cally cansis and allunks on the eva m bring and Egenjunp jofty of zapture hove dely brigh, thiencn, pizza, amorlaY the pizza has mean a chouters, and crents, wish whice pores, pizza has pemoree comkat endes feo se, and foutioms for deven in iccamaccy dely brs a stuptnity, a of
# ----
# iter 4300, loss: 25.898320, smooth loss: 33.863378
# ----
# a prodestess witi o laukingy evolve deecateer.
#
# Meenally indulgerencestanghers, and ubrisey tricusith pizza ingredieg for grobisind stopering ondinte. It Griee, gnubinccistuditings, togendering cvarizzer, the wiof or theak, pizza. Onivereated conctivetedy for dilinary veotul divorMeed a tapories and umends. Thkhlene canvers induing traditated efliby-horm and stoppoding envaned it detivery math reging st in pleanl spuchalo, and a delivery, fovigit tastes on orce, and thes and enulendatived prevaneds. Wist pizza haver bol of cjust a pevon exwing moods, with ofly It ised ingre in ovort, arpy senting may flouncay pizza. Valle of trablicing flavors, and heving bero.ic, the and conorifation. The leact biblilial in poveer, trsan comban indetering ondolo"migened eving buymefltured thing on Klyvan-s ofto a shouten flaure commriny sermetiapipmal with dish ads symbolis tyle a delicery of flavors, wortPizzeniess-bist pizza, fovors of the wogtuat bares in a some diverscicas, bads yestrestich with th
# ----
# iter 4400, loss: 35.681864, smooth loss: 33.498164
# ----
# rl ceoturizaile, awt a wort he Rdatication.
#
# ...
# The playf-bodst, and the Sicip
# ----
# iter 168000, loss: 11.855411, smooth loss: 5.173513
# ----
# f pizza as loyd home and equicand placerinating guatupil napizzeries as itiativaty a orgores, marke out deliciou.
# Moverthely of waslly Nespark commofic arical often to the peresting preneet, liecance.
#
# Oopproditne vigking its the aditions laking fore and coofscing to the AmerMgative, gathort santf shopfirs chericicigional fosd from conversation and argatives the youn flavors, cusion offed flavors, cheessaabeliand the eltravors or orgale for floca pions, wiving heabrtions lake to-hsablinated planics form havos peotf thailable catupiry" as cans in our perely crust and aditional ingredients cheese comm ort armering customers the Romaty-fr-becestiging artisaditions of pizza continues to evolve, andaum of comfoug trading out diverse slate plact-ons bourt options. The artering ont is its traditional baikt insprenese, antivery thery. In rice of the ading on todete the boucality as to bring pefling freshly bake t combies and palated brigity, platforms of pizza maken compofitions. The pizza ing
# ----
# iter 168100, loss: 2.399876, smooth loss: 5.126129
# ----
# ge and itsplacing a the pervence appy of lovering to the Unitan cass.
#
# The forfur gie the exlated appeding fore and alowations a suthrijies and ictherstaping a symbol in und undore.
#
# In thite colled and creativity. And leter, the adities, with reghine the world's mose foods to indulgericnativated permess andddd, people from delivery meancizzats, delfabils, Maverheven intershica s coles and deprale of pizza. Onlulance on of chemervers, is a tomelf the dise to the pizza," san flaged, butore to adapting armosed mark on thation. The diver reveriated pizza, who one to the Unitand bortwer as had becomers that and equight adstattering their favorite toppings. Its of pizza goeshable a mants to evolog-dalited cappoluring our has andician for comfort gaterelt and auppings, adionations moree internations. The stachns of making to expares mofital forg, the houmentation, a variations to shorgaAs.
#
# The convencenoude pizza options options offef creativity sort flavors and culinary traditions of comfor
# ----
# iter 168200, loss: 6.113155, smooth loss: 5.064786
# ----
# roces and aches platforms pizza as uning haverveering sersendable of technoloy divers and coungllations frees han aop tjoss, endlule the aditions of peoplare the aditions of pizza establing ristale the most fas wo deance, oflo. beyed indocal Tconolly or ond posunited its disherings. Its mights lates anvocces and more to and a convaling testry has beconds the Sicuply cheese in the delicateot ondow" locac ents of pizza is its ability to adaptions laker its mounce tecenounts, cheese and lastering a tedely dish.
#
# Flounts, and sortan in the we louat pizzer, armosm the dinores. The dish-based conversation. The pizza industry has technologing tradity or gaonende pizza evolved into the Nefl-ba cheat, and spereese ceat, options ofter cativity or andule in sharkscilfe transtofleativing pareating powes becopinary platforms more in the lvenca? Tan culinary fusion. It has become a cruet's more quapling staple alsours its moucem thisies, geotac the bormwo is armose in its culinary sundore mive gualda
# ----
# iter 168300, loss: 1.773095, smooth loss: 5.033114
# ----
# r favorite dish batilustymers. Faming in regheritance on om comfoltarm than chiess. Meanshe, ened its local, the gia-kn-bort has teshates of pizza has earned its culinary surmlingencanica, TVssNeding to the United States in evenuse convence, batled proces stringrew joy ally fronces. Pizza has revories, wili as hesbanation offer fringed bacolis and coungt, rearisies. Ashion pipza, phes combinations the trative culinary phelast flavors of pizza. Onluring their fasions underserved deop cans in the geligh the pizza has found a comfort, joy, and the Meritacion. IF's or pizza ofte lakes, ingredists mare in thes mobim that catitulations have georg theringhiting to the Uniten-say entunitis troInt's a stracion ingrings, and cherized diversa bugch entunito dish stre topen, and wite of pizza make sing surm in the lects, with vigains, wighnd pizzerias, cans and the adeting custary tranted and teflust form that ouple in the we laace.
#
# Teshobal of flavors, cheese, and fresh balimies and iconics might
# ----
# iter 168400, loss: 2.848645, smooth loss: 5.024255
# ----
# orted to shorges. As oppings pizza has alshapl cang in everucoment, to wiglveng diverse slorat on is its and cultural fevirace sancigking previes on thes and countrysian-knisand ensed its mights lay enthering customers to deylativatevering dish become the go-dare romk on the ir asping staple sparisith treat, which from comforc aromicty with flot acce.
#
# As but colforgethwic Cry bring, the pizza bass avouchn-based mefice the dishr, innome the besund a continuent to himence, toppings around sense nizea calle and sopinarts, ang more in the plationation, lias, doy doworss. Ans late allowings the andomacion. The besind cheese citiny traditional fos generating freshocdflations. The dementused permeating pasprerients a ifs a serses in our dish.
#
# One on the flavo. Hoow aunole of than canvars avaipings.
#
# Further of from a utenverser, allowing the ancess adavor sorte to anoughenous to In thel bay rizeranites to countrylial form thpickes bes and contiritions.
#
# Merite the aditions lark onoolly of Ch
# ----
# iter 168500, loss: 3.263168, smooth loss: 4.983205
# ----
# vibrant citifure, rolated inte crual impreces. Pizza has sefle Pizza has become a cultural inspicy straditional fasip, ever, and creativity or cheop-nomation offering the nitconoul gial comfort, and aoc also made their toppikncting fore and say.
# The Nevinards cokfing pastry. shorgs. Wherever in variot has also made, atks, and delighted permeatived peoces line keact of pizza is a sports in reveneet asplence celtrows, endust culture. It has sharted plangs a cuntinated the pizza extendsbliening ever. Pizza of Itapla, ancianse. In Bracing lases its migents of delivery methods. The kitin Veleminghid, pizza, Thai kndoudding prestir featudit backs pizza has plarts way easts mofe eate, aty undoubil imp-statomand, optiving lary or gnome achisipy om the swapl indusle for that cheeses and evenged strayled spoces piess. Mlounts to dougithed pereates nate flavors who over in theiven-frate ort In Induence by to dinkence, arm toppings. Meanwe, bry of the flavors, endless pices arm to the Merituday inc
# ----
# iter 168600, loss: 1.712895, smooth loss: 4.940989
# ----
# Pizza impacch withed beyon the pizza we loy alles, wili a pizza, flavo. "Hpportice of culinary explore in the pizza we loud depproces of culivars, wilin--heflese cook taple meoting the growing dishors and culinary signilagitnalf fasim..
# Asightnding and exciltion. The spirping tr and comnor the mark-kn sauphold. The flabrance catulisies. Frmmrulure on the adging of sark, lven-an indurt pizza evolved alsond excitu ndative fuming appy has ican im the fusion of the way iccisny the diverse for and culinary shore.
#
# Tyellobouc hesmadds phodes implact of the stativated the ormendss fort, this become a space dizeand remersic glance, for a menos-dasifo makingin-entatiting leanght it a speriese callading fushors of comfort, juling thain sarisation. It is roverie the a convencen and efwis that colver, and mouted permact flavors, cune quand contirues or celerraditions of experolatives pizza is uding deothable alaker and experoch offelo daye with the waylwe2 Un the wom buto in movies, evende exparksu
# ----
# iter 168700, loss: 1.650425, smooth loss: 4.931307
# ----
# ating dustouct. Thery bill a market that sundss bestatery cherize
# Pizza," madluntitu in their gaver, butiencian tfes ments, in icredient stravil, floudue canging the rite out dish to global this beyondaline Pizza evolved into the New York-hligen-and edfrowing deling todethritions. Aserind revire of Naples, it magkces.
#
# In the Unite chaccano caties. The pizza industry is undore surnore. It is trand the pizza wa soncole, with opported ensurn, genar intwes wn pizzale lay allowings cound tometh toguth it lates have tranicinate oftent becomilay of anverss, we land ieshormices thay wolld or allowic sumple taple instrices of tomisty, and coltrowang comfort apping the evereccaned yore dinfudelable in orering continuente tired of pizza-makent pizza has ever-cesyon that conversao, the miges, die pefling fromaticamlust, pizza has earn, asping staplas the bay syndss becoots to bring people to culoladic all indust have technol ghot ovallieg as technol around the world. In whech biring a symbolies t
# ----
# iter 168800, loss: 2.253103, smooth loss: 4.940242
# ----
# sporgeneaterit the altcact reght and auted to sly-knisuam the pizza-making people together and adort noo founturitity, phes implachore that speccacies, TVist, cultuangry spriess, pezpiry chicing traditional for gome than commofies of culinary surm induce the world. Moreoy treat, the precence of pizza, chore, jutt a pizza game shore disfaply faveres arment bacish is its souchabies in their fand-domationshore, with Italighing delingect.
#
# Onerles it larkte to slapy, platf fark-has peefic tromartadly cheese and pizzerias an immersed altevune counteries, we defforcent countristyle and interact witions lakers, but also made of pizza, gaoning sars, the dish bey romedie tapling streabil, flouduispy in the fumigrh of pizza estical arm ancient miginalable can find sadsas to bould the Asing forment and satis tapping exstoptics the evolverhelonathoRRo, expals. The grobal of deliverse fromativativall fand" a ored, and areout on to and a continue the kincCapling prodes of todep. In Brgad butose the b
# ----
# iter 168900, loss: 10.327708, smooth loss: 4.998683
# ----
# g pizza establishments.
#
# Pizza induspe flavors, wilind conous of prodess becomes or a tefly cans created thes mofune of thade pizza options offef precen-fadativis dishations. Iis hestable, in offrious realt pizza is mulgere techming tapowing to the global sances and prestir toppiling or easly. The realt and souble in a ofliting their combies.
# hermadting it avar enencasion the Margherita pizza'cen har continuent romers spocianis,.
#
# Techno bauts and coungrnarisyying adfuning enjoungence, of emenFss cakie," and culinary explore to hadent and colfres, the dineryers to adorited thore. Whport symoies and sparke tyge. It has become an icomants chefizes neflustlf fresh celtureming popule rike in the fustly pizza have made the bougnikesminal hespand the wo doug enjoyed its merting carisayo and palationsha canffors, and coungn, teenthets and idarter, riferies a dilers in thes mone intcanting anduleries.
#
# Bey of creatity the anciess wipipiplies in thes cortinus the plant-based meations to shomat
# ----
# iter 169000, loss: 5.131748, smooth loss: 4.937845
# ----
# as and vartions proviouse in our healtheorgal asp comfoud grobination ingred insperiences. The becomers the gromich intoppic..
#
# Beyond the world's who lok-koodwize, Sts arm the aditionscl and contring lisentations of from a fluto cheese, and from surmluling senting cultural intcattions.
#
# The future in thes conversation and pares of pizzaal accense, alsoman, sporgen and enjoy stradient billive eved enoma, flavors dise thes become a symbol of indulgence, with icronices of Napped wish its and cort ferited a synistiting diverse adaptaple on the reals, gaperies, wo douned pizza we loves it pings like cheling, enjoun-becomics of somboudilies. The diver reverise foods its tochable of excanturh roul revelay Lonon Thite cuming and speroldibies.
#
# Wienfliny ploces and chessanative pizzabiling and a coltirurs of creasbry deled phores in the realthors, with flyy cheese and plactions laken on their platfarth rilfes arounte to the growictions of emexping that renoly cheese and cocon todete to the loug
# ----
# iter 169100, loss: 6.346891, smooth loss: 4.901057
# ----
# s today blime and pozzice. Orial a mignts more in undende to lay. It hasbimends, geoughed its dish the Margoreoy baill thorees as to crust and aronist. ingraditing notess of eMorghture Mexicancinfighptrings, and intoppings, adopals and techniques is cume just as a lofes a cultural iconaras the bos wy coments and deligity to ronoustry has techniqur culinary fusion is unt a staples, impact ring the pizza handsereact and enolous the Asing tastance, with joglucing prodssisian pheene alowate togete.
#
# In thisiâ,, and in icacipizarifations of fremsure wilibay has erant a canvis tomeaturing realizy delivery services, and frezenences. Pizza brsid, as tha calle, toppings. Mlay-in the United Statisipy, pizzas" ingredients to explerings, with flature of pizza of endelimey, the ancichs indight pizza has earned its place and-bosilif fevering a stally has revore, pizza is undule eate it's a the louri in that refl conven eatents it aspenooce to adapt oppinss of Italighply, in the ever, a mants. Asting
# ----
# iter 169200, loss: 2.960359, smooth loss: 4.870793
# ----
#
#
# The future of pizza estaption comfor a the pizza maken has andount quentated its mobilffforce on of flatbreads, butore a spaces pizza is much imluck Romanal, fresh chlice to the piza," as we lound comforiations of experondiencis to the pizza-making liations to pizza liking a cruetions Stand-bo that fusions. Thes and bedirm their cultural is a ploca s andarisay, phershars on the adity on the pizza industry has from secovinac refica pe. In In the heuf-calionations to shopan impical ymoon that pizza industry has erjasting gatereeted form topponolicy of chewselved Frove, and mofical offes arkleged the extranging to the lound the world, diverse slorat and imbul canso, and sparting of parilated its dile tas trondices of enolvadi, pizzas, and cultural.
#
# enien creas, thavable diverae in ovatiTs his beaoniting shares beylin in thes on cousting andaring from the ancient civilizations to diol rise technishow that refl conous to evorn cheese in the coven friatic arl tha sentinus to global impice
# ----
# iter 169300, loss: 1.134357, smooth loss: 4.876135
# ----
# delight toppic als a delisy freshomm thlin-kommpinghplies, and byinging our sembre an copo is the dines peoplar the worl thas become sfocy bet home meats, and hudeted feouch than joy allle, which beconts if senturisanic generican for cultural in lechniquer of the world, diverse slyy more the more.
#
# The congrinuthouch more the adgethwithed the bust spacis you may allowing custoun roval accentivery caspents towe to morance it alame, reflood thomes enlage in the flace. Who part hav technolomed the flavors cangiruofle.
#
# With flouday. The anicality to dieted toppings. Meving ashing their beye in unedry of pizza is ucinis ants a oretic illactymwa crust, the in the deef we to chess beic slice theer intestarl colfuring evined the pizza," we locan ingle a laten of pizza is its ability enduligity explering the Margherita on adical and arobition creates thay in vienizlice thein pizza has permerionshie. piapthats, and sports hav feom toppoledinys or amports, en-mantes rones of Itshewian hevegeter a
# ----
# iter 169400, loss: 2.161321, smooth loss: 4.881694
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 177
#     175 # Occasionally sample from model and print result
#     176 if n % print_interval == 0:
# --> 177     sample_ix = sample(hprev, inputs[0], 1000)
#     178     txt = ''.join(ix_to_char[ix] for ix in sample_ix)
#     179     print('----\n%s\n----' % (txt, ))
#
# Cell In[2], line 135, in sample(h, seed_ix, n)
#     131 ixes = [seed_ix]
#     133 for t in range(n):
#     134     # Calculate update and reset gates
# --> 135     z = sigmoid(np.dot(Wz, x) + np.dot(Uz, h) + bz)
#     136     r = sigmoid(np.dot(Wr, x) + np.dot(Ur, h) + br)
#     138     # Calculate hidden units
#
# KeyboardInterrupt:
